# %%
import os
import json
import time
import random
import zipfile
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # Class Explanation: `NewsScraper`
#
# ## Overview
# The `NewsScraper` class is designed for scraping news articles from three different Urdu news websites: Geo, Jang, and Express. The class has methods that cater to each site's unique structure and requirements. Below, we will go through the class and its methods, detailing what each function does, the input it takes, and the output it returns.
#
# ## Class Definition
#
# ```python
# class NewsScraper:
#     def __init__(self, id_=0):
#         self.id = id_
# ```
#
#
# ## Method 1: `get_express_articles`
#
# ### Description
# Scrapes news articles from the Express website across categories like saqafat (entertainment), business, sports, science-technology, and world. The method navigates through multiple pages for each category to gather a more extensive dataset.
#
# ### Input
# - **`max_pages`**: The number of pages to scrape for each category (default is 7).
#
# ### Process
# - Iterates over each category and page.
# - Requests each category page and finds article cards within `<ul class='tedit-shortnews listing-page'>`.
# - Extracts the article's headline, link, and content by navigating through `<div class='horiz-news3-caption'>` and `<span class='story-text'>`.
#
# ### Output
# - **Returns**: A tuple of:
#   - A Pandas DataFrame containing columns: `id`, `title`, and `link`).
#   - A dictionary `express_contents` where the key is the article ID and the value is the article content.
#
# ### Data Structure
# - Article cards are identified by `<li>` tags.
# - Content is structured within `<span class='story-text'>` and `<p>` tags.

# %% [markdown]
# ### Other websites used
#
# Here we have used two more websites for our webscraping:
# - Geo News
# - Jang News

# %%
class NewsScraper:
    def __init__(self,id_=0):
        self.id = id_


    # write functions to scrape from other websites
    def get_geo_articles(self, max_pages=7):
        geo_df = {
            "id": [],
            "title": [],
            "link": [],
            "content": [],
            "gold_label": [],
        }
        base_url = 'https://urdu.geo.tv/category'
        categories = ['entertainment', 'business', 'sports', 'science-technology', 'world']   # saqafat is entertainment category

        # Iterating over the specified number of pages
        for category in categories:
            for page in range(1, 2):
                print(f"Scraping page {page} of category '{category}'...")
                url = f"{base_url}/{category}/archives?page={page}"
                response = requests.get(url)
                response.raise_for_status()
                soup = BeautifulSoup(response.text, "html.parser")

                # Finding article cards
                cards = soup.find_all('div', class_ = "col-xs-6 col-sm-6 col-lg-6 col-md-6 singleBlock")

                print(f"\t--> Found {len(cards)} articles on page {page} of '{category}'.")

                success_count = 0

                for card in cards:
                    try:
                        div = card.find('ul')
                        div = div.find("li")
                        
                        # Article Title
                        headline = div.find('a').get_text(strip=True).replace('\xa0', ' ')
                        
                        # Article link
                        link = div.find('a')['href']
                        
                        # Requesting the content from each article's link
                        article_response = requests.get(link)
                        article_response.raise_for_status()
                        content_soup = BeautifulSoup(article_response.text, "html.parser")

                        # Content arranged in paras inside <span> tags
                        paras = content_soup.find('div',class_='content-area').find_all('p')

                        combined_text = " ".join(
                        p.get_text(strip=True).replace('\xa0', ' ').replace('\u200b', '')
                        for p in paras if p.get_text(strip=True)
                        )

                        # Storing data
                        geo_df['id'].append(self.id)
                        geo_df['title'].append(headline)
                        geo_df['link'].append(link)
                        geo_df['gold_label'].append(category)
                        geo_df['content'].append(combined_text)

                        # Increment ID and success count
                        self.id += 1
                        success_count += 1

                        # print(f"\t--> Successfully scraped {success_count} articles from page {page} of '{category}'.")

                    except Exception as e:
                        print(f"\t--> Failed to scrape an article on page {page} of '{category}': {e}")

                print(f"\t--> Successfully scraped {success_count} articles from page {page} of '{category}'.")
        
        return pd.DataFrame(geo_df)
    
    
    
    def get_jang_articles(self):
        jang_df = {
            "id": [],
            "title": [],
            "link": [],
            "content": [],
            "gold_label": [],
        }
        base_url = 'https://jang.com.pk'
        categories = ['entertainment', 'business', 'sports', 'health-science', 'world']
        
        
        for category in categories:
            print(f"Scraping category '{category}'...")
            url = f'{base_url}/category/latest-news/{category}'
            
            response = requests.get(url)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, "html.parser")
            
            cards=soup.find('ul', class_='scrollPaginationNew__').find_all('li')
            print(f"\t--> Found {len(cards)} articles of {category}.")
            
            success_count = 0
            
            for card in cards:
                try:
                    div = card.find('div',class_='main-heading')
                    
                    headline = div.find('a').get_text(strip=True).replace('\xa0', ' ')

                    link = div.find('a')['href']

                    article_response = requests.get(link)
                    article_response.raise_for_status()
                    content_soup = BeautifulSoup(article_response.text, "html.parser")
                                        
                    paras = content_soup.find('div', class_='detail_view_content').find_all('p')

                    combined_text = " ".join(
                    p.get_text(strip=True).replace('\xa0', ' ').replace('\u200b', '')
                    for p in paras if p.get_text(strip=True)
                    )
                    
                    # Storing data
                    jang_df['id'].append(self.id)
                    jang_df['title'].append(headline)
                    jang_df['link'].append(link)
                    jang_df['gold_label'].append(category.replace('health-science','science-technology'))
                    jang_df['content'].append(combined_text)

                    # Increment ID and success count
                    self.id += 1
                    success_count += 1

                except Exception as e:
                    print(f"\t--> Failed to scrape an article of '{category}': {e}")

            print(f"\t--> Successfully scraped {success_count} articles of '{category}'.")
        
        return pd.DataFrame(jang_df)
             


    def get_express_articles(self, max_pages=7):
        express_df = {
            "id": [],
            "title": [],
            "link": [],
            "content": [],
            "gold_label": [],
        }
        base_url = 'https://www.express.pk'
        categories = ['saqafat', 'business', 'sports', 'science', 'world']   # saqafat is entertainment category

        # Iterating over the specified number of pages
        for category in categories:
            for page in range(1, max_pages + 1):
                print(f"Scraping page {page} of category '{category}'...")
                url = f"{base_url}/{category}/archives?page={page}"
                response = requests.get(url)
                response.raise_for_status()
                soup = BeautifulSoup(response.text, "html.parser")

                # Finding article cards
                cards = soup.find('ul', class_='tedit-shortnews listing-page').find_all('li')  # Adjust class as per actual site structure
                print(f"\t--> Found {len(cards)} articles on page {page} of '{category}'.")

                success_count = 0

                for card in cards:
                    try:
                        div = card.find('div',class_='horiz-news3-caption')

                        # Article Title
                        headline = div.find('a').get_text(strip=True).replace('\xa0', ' ')

                        # Article link
                        link = div.find('a')['href']
                        print('link in express is', link)

                        # Requesting the content from each article's link
                        article_response = requests.get(link)
                        article_response.raise_for_status()
                        content_soup = BeautifulSoup(article_response.text, "html.parser")


                        # Content arranged in paras inside <span> tags
                        paras = content_soup.find('span',class_='story-text').find_all('p')

                        combined_text = " ".join(
                        p.get_text(strip=True).replace('\xa0', ' ').replace('\u200b', '')
                        for p in paras if p.get_text(strip=True)
                        )

                        # Storing data
                        express_df['id'].append(self.id)
                        express_df['title'].append(headline)
                        express_df['link'].append(link)
                        express_df['gold_label'].append(category.replace('saqafat','entertainment').replace('science','science-technology'))
                        express_df['content'].append(combined_text)

                        # Increment ID and success count
                        self.id += 1
                        success_count += 1

                    except Exception as e:
                        print(f"\t--> Failed to scrape an article on page {page} of '{category}': {e}")

                print(f"\t--> Successfully scraped {success_count} articles from page {page} of '{category}'.")
            print('')

        return pd.DataFrame(express_df)

# %%
scraper = NewsScraper()

# %% [markdown]
# ### Output
#
# - Getting the articles from all websites and combinig the results in a csv file
# - Created `articles.csv`

# %%
geo_df=scraper.get_geo_articles()
jang_df=scraper.get_jang_articles()
express_df=scraper.get_express_articles()

combined_df=pd.concat([geo_df, jang_df, express_df], ignore_index=True)

combined_df=combined_df.rename(columns={
    'id': 'Article IDs',
    'link': 'Links', 
    'title': 'Titles', 
    'content': 'Contents', 
    'gold_label': 'Gold Labels'
})

combined_df.to_csv('articles.csv', index=False)
# Out:
# Scraping page 1 of category 'entertainment'...
# 	--> Found 60 articles on page 1 of 'entertainment'.
# 	--> Successfully scraped 60 articles from page 1 of 'entertainment'.
# Scraping page 1 of category 'business'...
# 	--> Found 60 articles on page 1 of 'business'.
# 	--> Successfully scraped 60 articles from page 1 of 'business'.
# Scraping page 1 of category 'sports'...
# 	--> Found 60 articles on page 1 of 'sports'.
# 	--> Successfully scraped 60 articles from page 1 of 'sports'.
# Scraping page 1 of category 'science-technology'...
# 	--> Found 60 articles on page 1 of 'science-technology'.
# 	--> Successfully scraped 60 articles from page 1 of 'science-technology'.
# Scraping page 1 of category 'world'...
# 	--> Found 60 articles on page 1 of 'world'.
# 	--> Successfully scraped 60 articles from page 1 of 'world'.
# Scraping category 'entertainment'...
# 	--> Found 101 articles of entertainment.
# 	--> Failed to scrape an article of 'entertainment': 'NoneType' object has no attribute 'find'
# 	--> Failed to scrape an article of 'entertainment': 'NoneType' object has no attribute 'find'
# 	--> Successfully scraped 99 articles of 'entertainment'.
# Scraping category 'business'...
# 	--> Found 99 articles of business.
# 	--> Failed to scrape an article of 'business': 'NoneType' object has no attribute 'find'
# 	--> Failed to scrape an article of 'business': 'NoneType' object has no attribute 'find'
# 	--> Successfully scraped 97 articles of 'business'.
# Scraping category 'sports'...
# 	--> Found 100 articles of sports.
# 	--> Failed to scrape an article of 'sports': 'NoneType' object has no attribute 'find'
# 	--> Failed to scrape an article of 'sports': 'NoneType' object has no attribute 'find'
# 	--> Successfully scraped 98 articles of 'sports'.
# Scraping category 'health-science'...
# 	--> Found 101 articles of health-science.
# 	--> Failed to scrape an article of 'health-science': 'NoneType' object has no attribute 'find'
# 	--> Failed to scrape an article of 'health-science': 'NoneType' object has no attribute 'find'
# 	--> Successfully scraped 99 articles of 'health-science'.
# Scraping category 'world'...
# 	--> Found 102 articles of world.
# 	--> Failed to scrape an article of 'world': 'NoneType' object has no attribute 'find'
# 	--> Failed to scrape an article of 'world': 'NoneType' object has no attribute 'find'
# 	--> Successfully scraped 100 articles of 'world'.
# Scraping page 1 of category 'saqafat'...
# 	--> Found 10 articles on page 1 of 'saqafat'.
# link in express is https://www.express.pk/story/2732223/sidharthmalhotra-marutisuzuki-ki-gadi-desire-ke-brand-ambassador-muqarar
# link in express is https://www.express.pk/story/2732220/karanjohar-ki-ramance-ki-dunya-me-wapsi-chandmeradil-ke-nam-se-film-ka-elan
# link in express is https://www.express.pk/story/2732217/jimmyshergill-tamannahbhatia-avinash-ki-thriller-film-sikandarkamuqadar-kb-release-hogi
# link in express is https://www.express.pk/story/2732203/talaq-ki-news-aishwary-or-abhishek-nayi-film-me-sath-nazar-aayen-gay
# link in express is https://www.express.pk/story/2732200/salmankhan-ke-shooting-set-par-70-se-zayed-securitypersonal-mojod
# link in express is https://www.express.pk/story/2732194/chanduchampion-bhoolbhulyaan3-ke-sath-kartikaryan-ne-new-record-bana-dia
# link in express is https://www.express.pk/story/2732186/pushpa2-ki-khatarnak-jhalak-jari-alluarjun-or-fahadfasil-ki-tasveer-jari
# link in express is https://www.express.pk/story/2732181/urfijaved-ne-tripitidimri-ko-dance-seekhne-ka-mashwara-de-dia
# link in express is https://www.express.pk/story/2732176/falakshabir-ne-marriedlife-ko-happy-banane-ka-secret-batadia
# link in express is https://www.express.pk/story/2732174/aaliabhatt-ne-raha-ki-birthday-par-unseen-pic-share-kardi
# 	--> Successfully scraped 10 articles from page 1 of 'saqafat'.
# Scraping page 2 of category 'saqafat'...
# 	--> Found 10 articles on page 2 of 'saqafat'.
# link in express is https://www.express.pk/story/2732170/mai-sans-lena-chahti-hon-saba-qamar-ka-lahore-ki-smog-par-tabsara
# link in express is https://www.express.pk/story/2732157/influencers-nojawano-main-depression-ki-waja-ban-rahy-hen-zoya-nasir
# link in express is https://www.express.pk/story/2732145/kabhi-main-kabhi-tm-ki-adakara-naaema-but-ko-social-media-pr-trolling-ka-samna
# link in express is https://www.express.pk/story/2732131/sidhu-moosy-wala-wapas-agaya-gulukar-k-nanhy-bhai-ki-tasweer-viral
# link in express is https://www.express.pk/story/2732124/turkey-k-sultan-salah-uddin-ayyubi-star-ka-pakistan-ane-ka-elaan
# link in express is https://www.express.pk/story/2732113/nauman-ejaz-or-saba-qamat-bold-manazir-filmane-pr-tanqeed-ki-zad-main
# link in express is https://www.express.pk/story/2732103/salman-khan-or-bishnoi-pr-gana-likhne-wala-writer-bishnoi-gang-k-nishane-pr
# link in express is https://www.express.pk/story/2732061/zeenataman-ki-12years-bad-izdiwaji-zindgai-chorne-ki-asal-waja-samne-agayi
# link in express is https://www.express.pk/story/2732057/alifazal-or-richachaddha-ki-nanhi-pari-ka-naam-samne-aagya
# link in express is https://www.express.pk/story/2732055/pakstani-flmi-staro-ka-srkari-aaazazat-oaps-krn-ka-aaalan
# 	--> Successfully scraped 10 articles from page 2 of 'saqafat'.
# Scraping page 3 of category 'saqafat'...
# 	--> Found 10 articles on page 3 of 'saqafat'.
# link in express is https://www.express.pk/story/2732050/maniratnam-or-kamalhassan-ki-37years-bad-wapsi-thuglife-ka-teaser-release
# link in express is https://www.express.pk/story/2732044/shadi-ke-baad-amnamalik-ko-kin-haqiqaton-ka-samna-karna-para
# link in express is https://www.express.pk/story/2732030/salmankhan-ko-dhamki-dene-wala-shaks-arrest-lawrancebishnoi-ka-fan-nikla
# link in express is https://www.express.pk/story/2732026/newprject-newstyle-parinitichopra-ka-ishara-madah-tajassus-main-mubtila
# link in express is https://www.express.pk/story/2732022/oki-koshl-aor-alo-arjn-ki-flmo-ki-riliz-tarikho-mi-tbdili-baks-aafs-pr-bi-kr-s-ajtnab
# link in express is https://www.express.pk/story/2732018/deepikapadukon-or-ranvirsingh-ki-beti-ke-name-par-tanaza-name-dua-kyun-rakha
# link in express is https://www.express.pk/story/2732017/ranbirkapoor-ke-fans-kelye-goodnews-animalpark-ka-wait-end-honay-wala-hai
# link in express is https://www.express.pk/story/2732006/sunil-shetty-hadsy-ka-shikar-shadid-zakhmi-hogaye
# link in express is https://www.express.pk/story/2732001/khalil-ur-rehman-honeytrap-case-me-aham-peshraft
# link in express is https://www.express.pk/story/2731990/salman-khan-k-baad-shahrukh-khan-ko-bhi-qatal-ki-dhamki-mil-gai
# 	--> Successfully scraped 10 articles from page 3 of 'saqafat'.
# Scraping page 4 of category 'saqafat'...
# 	--> Found 10 articles on page 4 of 'saqafat'.
# link in express is https://www.express.pk/story/2731983/cancer-ki-tashkhis-pr-lga-taa-marne-wali-hon-manisha-koirala
# link in express is https://www.express.pk/story/2731972/british-parliament-ne-mahira-khan-ko-bary-ayzaz-se-nawaz-dia
# link in express is https://www.express.pk/story/2731960/sar-ali-khan-or-sidhart-malhotra-ne-nai-film-sign-krli-kb-release-hogi
# link in express is https://www.express.pk/story/2731949/nadia-khan-ne-zindagi-ki-sb-se-bari-ghalti-kis-ko-karar-dia
# link in express is https://www.express.pk/story/2731930/aj-ka-din-kaisa-rahe-ga
# link in express is https://www.express.pk/story/2731901/richachadda-or-alifazal-ki-film-girlswillbegirls-gothamawards-kelie-select
# link in express is https://www.express.pk/story/2731899/ranbirkapoor-or-vickykaushal-ki-film-lovewar-ki-shooting-start
# link in express is https://www.express.pk/story/2731897/salmankhan-ko-10din-me-dosri-dhamki-mumbaipolice-ne-security-sakht-kardi
# link in express is https://www.express.pk/story/2731890/karachi-me-8th-adabfestival-sunday-ko-hoga
# link in express is https://www.express.pk/story/2731880/shahrukhkhan-ki-veerzaara-600-sy-zayed-screens-par-rerealease
# 	--> Successfully scraped 10 articles from page 4 of 'saqafat'.
# Scraping page 5 of category 'saqafat'...
# 	--> Found 10 articles on page 5 of 'saqafat'.
# link in express is https://www.express.pk/story/2731873/actressmumtaz-ka-badobadi-song-ka-mazaq-banane-par-singer-par-barhami-ka-izhar
# link in express is https://www.express.pk/story/2731869/salmankhan-or-rashmikamandana-ki-film-sikhandar-ki-shooting-videos-viral
# link in express is https://www.express.pk/story/2731859/indiancinema-ki-biggest-film-ka-elan-release-ki-dates-bhi-agayeen
# link in express is https://www.express.pk/story/2731854/barti-ripr-ni-sng-n-pakstani-glokar-ko-kri-d-kr-mdaho-k-dl-jit-li
# link in express is https://www.express.pk/story/2731849/khaton-mdah-ki-bri-p-k-sat-naziba-hrkt-oiio-oaerl
# link in express is https://www.express.pk/story/2731844/mahira-khan-or-humayyun-saeed-cinema-pr-aik-sath-jalwagar-hone-ko-tayar
# link in express is https://www.express.pk/story/2731811/amriki-antikhabat-main-reema-ne-kis-ko-vote-dia-taswir-viral
# link in express is https://www.express.pk/story/2731795/kamla-haris-ya-trump-the-simpsons-ne-amriki-intikhabat-mai-kis-ki-jeet-ki-peshgoi-ki-thi
# link in express is https://www.express.pk/story/2731771/agar-kangna-amrici-shehri-hoti-to-kis-ko-vote-dalti-adakara-ka-bian-viral
# link in express is https://www.express.pk/story/2731764/kbhi-main-kbhi-tm-ka-muhabbat-bhara-ikhtitam-sharjina-or-mustufa-aik-hogaye
# 	--> Successfully scraped 10 articles from page 5 of 'saqafat'.
# Scraping page 6 of category 'saqafat'...
# 	--> Found 10 articles on page 6 of 'saqafat'.
# link in express is https://www.express.pk/story/2731730/ahsan-khan-and-chris-gayle-dance-viral-video
# link in express is https://www.express.pk/story/2731719/pakistani-actress-laiba-khan-perform-umrah-with-family
# link in express is https://www.express.pk/story/2731713/anushka-sharma-shares-son-akaays-first-photo-on-virat-kohlis-birthday
# link in express is https://www.express.pk/story/2731697/shah-rukh-khan-meets-jharkhand-man-who-waited-95-days-outside-mannat
# link in express is https://www.express.pk/story/2731693/resham-raise-voice-for-nargis
# link in express is https://www.express.pk/story/2731675/ani-aaamr-mar-khan-ka-asael-kapi-kr-ri-i-soshl-miia-pr-nei-bhth-chgei
# link in express is https://www.express.pk/story/2731669/abhishek-bachen-ki-nai-film-i-want-to-talk-ka-trailer-jari
# link in express is https://www.express.pk/story/2731647/bharti-talib-ilm-ki-mukhtasir-film-ne-oscars-2025-qualify-krlia
# link in express is https://www.express.pk/story/2731635/bharti-adakara-ka-madina-munawara-mein-nikkah-tasawir-viral
# link in express is https://www.express.pk/story/2731624/mahira-khan-ko-shahrukh-ki-konsi-bat-ne-behad-mutasir-kia
# 	--> Successfully scraped 10 articles from page 6 of 'saqafat'.
# Scraping page 7 of category 'saqafat'...
# 	--> Found 10 articles on page 7 of 'saqafat'.
# link in express is https://www.express.pk/story/2731613/smanta-prbo-n-flmo-mi-apni-nakami-ka-aaatraf-krlia
# link in express is https://www.express.pk/story/2731604/mandir-main-maaafi-mango-ya-5-crore-do-salman-khan-ko-phr-qatal-ki-dhamki
# link in express is https://www.express.pk/story/2731548/salmankhan-ki-dhamkion-ke-bawajood-sikandar-ki-shooting-jari
# link in express is https://www.express.pk/story/2731546/ajaydavgan-ki-singhamagain-ne-3dino-main-126-crore-business-kar-lia
# link in express is https://www.express.pk/story/2731537/amitabhbachachan-ke-show-kbc-ko-historicalerror-pr-tanqeed-ka-samna
# link in express is https://www.express.pk/story/2731524/shahrukhkhan-ne-apni-salgirah-par-police-ko-khana-bhej-ka-dil-jeet-lye
# link in express is https://www.express.pk/story/2731515/kartk-aarian-ki-bol-blia-3-n-100-kro-ka-sng-mil-aabor-krlia
# link in express is https://www.express.pk/story/2731508/diljitdosanjh-ka-jaipur-concert-main-marvari-fan-ke-sath-stag-par-bhangda
# link in express is https://www.express.pk/story/2731503/americansinger-ne-nationalantheme-ke-doran-gali-dene-par-mafi-mang-li
# link in express is https://www.express.pk/story/2731496/dunki-or-judwa2-me-kam-par-tawaqa-se-kam-mawaza-mila-tapssipannu
# 	--> Successfully scraped 10 articles from page 7 of 'saqafat'.
#
# Scraping page 1 of category 'business'...
# 	--> Found 10 articles on page 1 of 'business'.
# link in express is https://www.express.pk/story/2732196/karachi-balochistan-sanatkaru-garian-bhata-talab
# link in express is https://www.express.pk/story/2732193/october-mein-beron-mumalik-muqeem-pakistanio-ne-3-1-arab-dollar-ki-tarseelat-bhejen
# link in express is https://www.express.pk/story/2732190/pakstan-aor-abothbi-ki-kmpni-k-drmian-mkhtlf-shaabo-mi-taaaon-ki-iaddashto-pr-dskhtt
# link in express is https://www.express.pk/story/2732184/bldi-aathmi-ki-markio-ko-solrssm-pr-mntkl-krdia-jae-ga-mierkrachi
# link in express is https://www.express.pk/story/2732179/zar-e-mubadla-ki-marketon-mein-chaar-roz-ke-baad-rupay-ki-qader-mein-izafah
# link in express is https://www.express.pk/story/2732177/aif-bi-aar-ko-mosol-ankm-iks-goshoaro-mi-76-fisd-adaf
# link in express is https://www.express.pk/story/2732175/mlk-mi-mngaei-ki-shrh-mi-mslsl-adaf
# link in express is https://www.express.pk/story/2732129/gold-prices-for-08-11-24
# link in express is https://www.express.pk/story/2732128/stock-exchange-me-aik-bar-phr-tareekh-raqam-index-nai-buland-tareen-satah-par
# link in express is https://www.express.pk/story/2732122/guzishta-mao-tarseelat-e-zar-me-31-arab-dollars-ki-record-amad
# 	--> Successfully scraped 10 articles from page 1 of 'business'.
# Scraping page 2 of category 'business'...
# 	--> Found 10 articles on page 2 of 'business'.
# link in express is https://www.express.pk/story/2732121/maaishi-sargarmian-anay-walay-dino-mein-mazeed-barhain-gi-governor-state-bank
# link in express is https://www.express.pk/story/2732093/fly-jinnah-ne-kamyaab-taraqqi-ke-dosray-saal-ka-sang-e-mil-uboor-kya
# link in express is https://www.express.pk/story/2732083/pia-doobti-rahi-fraud-karne-walon-ko-kabhi-pakra-nahi-gaya
# link in express is https://www.express.pk/story/2732060/ailon-msk-ki-dolt-mi-onl-rmp-ki-jit-k-baad-hiran-kn-adaf
# link in express is https://www.express.pk/story/2732038/zrmbadl-k-srkari-thkhaer-mi-adaf-kmrshl-binko-k-thkhaer-mi-kmi
# link in express is https://www.express.pk/story/2732029/donald-trmp-ki-kamyabi-zar-e-mubadla-ki-dono-marketon-mein-dollar-ki-paish-qadmi-barqarar
# link in express is https://www.express.pk/story/2732004/pakistan-m-50-fisad-se-zyada-cigarette-ki-gair-qanoni-farookht-ka-inkishaf
# link in express is https://www.express.pk/story/2731997/trump-ki-kamiyabi-ke-bad-sone-ki-qeemt-min-bari-kami
# link in express is https://www.express.pk/story/2731974/utility-stores-m-sugar-ki-per-kg-qeemat-m-bari-kami
# link in express is https://www.express.pk/story/2731962/sifc-ki-madad-se-pakistan-australian-zarai-maharat-ka-nifaaz
# 	--> Successfully scraped 10 articles from page 2 of 'business'.
# Scraping page 3 of category 'business'...
# 	--> Found 10 articles on page 3 of 'business'.
# link in express is https://www.express.pk/story/2731936/ecc-ne-murghi-aur-daalon-ki-qeematon-mein-izafay-kanots-le-liya
# link in express is https://www.express.pk/story/2731884/tajawizat-ke-khilaf-operation-shuru-md-site-gazenfer-qadri
# link in express is https://www.express.pk/story/2731858/zarmubadilah-ki-donon-marketon-main-doller-ki-qadar-main-utar-chadhao-ke-bad-izafah
# link in express is https://www.express.pk/story/2731836/trump-ke-jeetane-par-kham-teel-ki-qeemton-min-kami-dollar-ki-qadar-mazboot
# link in express is https://www.express.pk/story/2731834/gold-prices-for-06-11-2024
# link in express is https://www.express.pk/story/2731807/power-project-kiliye-thatta-min-1674-acre-arazi-naji-company-ko-dine-ki-manzuri
# link in express is https://www.express.pk/story/2731804/stock-exchange-me-aaj-bhi-taizi-index-nai-buland-satah-par-pohnch-gya
# link in express is https://www.express.pk/story/2731803/fbr-ki-tajir-dost-scheme-m-bari-tabdeeliaa-mutwaqqay
# link in express is https://www.express.pk/story/2731775/maashi-shobon-se-nikal-jana-hi-hukomat-ke-haq-min-behtar-hay-wazir-e-khazana
# link in express is https://www.express.pk/story/2731773/10-alr-ka-pakstani-am-dbei-mi-dobar-pik-okr-120alr-ka-ojata-io-a-ai-konslr
# 	--> Successfully scraped 10 articles from page 3 of 'business'.
# Scraping page 4 of category 'business'...
# 	--> Found 10 articles on page 4 of 'business'.
# link in express is https://www.express.pk/story/2731767/fbr-min-89-khali-aasamiyan-khatam-kardi-gayin
# link in express is https://www.express.pk/story/2731752/bijli-ki-khareed-o-farokht-mein-1075-arab-rupay-ka-short-faal
# link in express is https://www.express.pk/story/2731683/zar-e-mubadla-ki-marketon-mein-atarchrhhao-ke-baad-dollar-ki-paish-qadmi-barqarar
# link in express is https://www.express.pk/story/2731653/gold-prices-05-11-24
# link in express is https://www.express.pk/story/2731606/pakistan-stock-exchange-me-aaj-phir-taizi-index-92-hazar-points-ki-satah-uboor-kar-gya
# link in express is https://www.express.pk/story/2731587/karachi-chamber-ne-sharah-sood-mein-mamooli-kami-mustard-kar-di
# link in express is https://www.express.pk/story/2731583/2-8-ki-sharah-se-taraqqi-karen-ge-tab-bhi-bijli-mehngi-hogi-owais-laghari
# link in express is https://www.express.pk/story/2731542/ecc-ne-rawan-maali-saal-keliye-circular-debt-managment-plan-ki-manzoori-day-di
# link in express is https://www.express.pk/story/2731538/almi-bank-ki-tawanai-or-zarai-o-ghizai-ashiya-ki-qeemton-main-kami-ki-pesh-goi
# link in express is https://www.express.pk/story/2731520/chini-electric-gadiyon-par-100-fisad-anti-dumping-duty-se-pakistan-k-liye-amkanat-roshan
# 	--> Successfully scraped 10 articles from page 4 of 'business'.
# Scraping page 5 of category 'business'...
# 	--> Found 10 articles on page 5 of 'business'.
# link in express is https://www.express.pk/story/2731512/aktobrmin-cement-ki-farokht-mein-8-74-feesad-izafah-record
# link in express is https://www.express.pk/story/2731500/interbank-and-open-market-dollar-rate-increase
# link in express is https://www.express.pk/story/2731487/state-bank-ne-monitory-policy-ka-elan-kerdia-sharah-sood-men-dhai-fesad-kami
# link in express is https://www.express.pk/story/2731485/son-ki-aaalmi-aor-mkami-markio-mi-kimt-mi-adaf-ogia
# link in express is https://www.express.pk/story/2731465/matrooka-waqf-action-committee-ka-jaidad-ke-rent-m-izafae-ke-khilaf-ehtijaj-ka-elaan
# link in express is https://www.express.pk/story/2731435/pakistan-stock-exchange-me-record-saaz-taizi-index-nai-buland-tareen-satah-par-pohnch-gya
# link in express is https://www.express.pk/story/2731417/2050-tak-pakistan-mein-tawanai-ki-talabb-mein-ghair-mamooli-izafah-mutawaqqa
# link in express is https://www.express.pk/story/2731416/monitory-policy-committee-ka-aaj-ijlaas-sharah-sood-mein-2-feesad-tak-kami-mutawaqqa
# link in express is https://www.express.pk/story/2731412/zar-e-mubadla-ke-sarkari-zakhair-11-16-arab-majmoi-16-05-arab-dollar-record
# link in express is https://www.express.pk/story/2731411/zameen-ki-taqseem-dar-taqseem-zarayi-pedawar-ko-mutasir-karne-ka-sabab
# 	--> Successfully scraped 10 articles from page 5 of 'business'.
# Scraping page 6 of category 'business'...
# 	--> Found 10 articles on page 6 of 'business'.
# link in express is https://www.express.pk/story/2731411/zameen-ki-taqseem-dar-taqseem-zarayi-pedawar-ko-mutasir-karne-ka-sabab
# link in express is https://www.express.pk/story/2731387/significant-cut-expected-in-policy-rate
# link in express is https://www.express.pk/story/2731340/oziraaathm-shbaz-shrif-ki-brtani-k-baathr-karobari-shkhsiat-ko-srmai-kari-ki-daaot
# link in express is https://www.express.pk/story/2731335/koi-bhi-sobai-hakomat-pia-khareedna-chaay-hamin-etiraz-nihen-wazir-nijkari
# link in express is https://www.express.pk/story/2731334/cotton-ki-production-min-record-azafe-ka-imkan
# link in express is https://www.express.pk/story/2731290/revenue-short-faal-imf-ka-izafi-revenue-keliye-iqdamaat-ka-mutalba
# link in express is https://www.express.pk/story/2731289/state-bank-ne-digital-currency-ko-qanooni-qarar-dainay-ki-tajweez-day-di
# link in express is https://www.express.pk/story/2731251/bachatscheme-certificate-munafa-sharah-kami
# link in express is https://www.express.pk/story/2731250/imf-nazarsani-darkhwast-mustarad-sadaqat-nahi
# link in express is https://www.express.pk/story/2731224/mkami-aor-bin-alakoami-marki-mi-son-ki-kmit-mi-kmi
# 	--> Successfully scraped 10 articles from page 6 of 'business'.
# Scraping page 7 of category 'business'...
# 	--> Found 10 articles on page 7 of 'business'.
# link in express is https://www.express.pk/story/2731217/imf-ka-fbr-se-do-moor-ka-mutaliba
# link in express is https://www.express.pk/story/2731137/4-mah-main-tijarti-khasara-6974-arab-dollar-record
# link in express is https://www.express.pk/story/2731136/pia-ki-nijkari-ka-amal-aik-mukammal-failier-tha-shahbaz-rana
# link in express is https://www.express.pk/story/2731135/mehngai-main-hafta-war-010-mahana-12-fisad-izafa
# link in express is https://www.express.pk/story/2731128/maniri-palisi-kmii-shrh-sod-mi-500-bi-pi-ais-kmi-kr-sdr-aif-pi-si-si-aaei
# link in express is https://www.express.pk/story/2731117/ktr-pakstan-mi-3-arb-alr-ki-srmai-kari-kr-ga-ozir-atlaaaat
# link in express is https://www.express.pk/story/2731114/pakistanorlitovia-taxchori-bachaw-muahida
# link in express is https://www.express.pk/story/2731108/ozart-dfaaa-k-jazo-kile-18-arb-alr-dmni-gran-ki-mnthori
# link in express is https://www.express.pk/story/2731104/malisal-ibtidai4mah-daramdat-baramdat-izafa
# link in express is https://www.express.pk/story/2731093/pakistan-stock-market-men-waqfe-ke-bad-tezi
# 	--> Successfully scraped 10 articles from page 7 of 'business'.
#
# Scraping page 1 of category 'sports'...
# 	--> Found 10 articles on page 1 of 'sports'.
# link in express is https://www.express.pk/story/2732206/qumi-women-one-day-cricket-waqar-younus-jeth-aliya-hamza-bhawej
# link in express is https://www.express.pk/story/2732204/pnjab-ki-bdtrin-asmog-aor-fdaei-alodgi-s-kaed-aaathm-rafi-ornamn-bi-mtathr
# link in express is https://www.express.pk/story/2732167/champions-trophy-ke-lye-indina-media-nahi-bharti-hukumet-ke-muntazir-han-mohsin-naqvi
# link in express is https://www.express.pk/story/2732164/chimpeinz-rafi-barti-miia-ka-ba-daaoi-chiermin-pi-si-bi-ka-joabi-oar
# link in express is https://www.express.pk/story/2732158/tarikhi-fth-k-iro-harth-n-am-sng-mil-apn-nam-krlia
# link in express is https://www.express.pk/story/2732153/srf-balz-pr-foks-kia-i-ni-dika-kon-balng-kroa-ra
# link in express is https://www.express.pk/story/2732141/rizwan-equaled-the-record-of-most-catches-in-one-match
# link in express is https://www.express.pk/story/2732132/rizwan-xi-changed-28-years-old-history-at-adelaide
# link in express is https://www.express.pk/story/2732127/annual-award-ceremony-of-ihf-will-be-held-today-in-muscat
# link in express is https://www.express.pk/story/2732119/ricky-ponting-advised-babar-azam-to-take-a-break-from-the-cricket
# 	--> Successfully scraped 10 articles from page 1 of 'sports'.
# Scraping page 2 of category 'sports'...
# 	--> Found 10 articles on page 2 of 'sports'.
# link in express is https://www.express.pk/story/2732110/champions-trophy-icc-gives-india-one-week-to-confirm-pakistan-tour-plans
# link in express is https://www.express.pk/story/2732109/afghan-batter-mohammad-nabi-will-retire-after-the-champions-trophy
# link in express is https://www.express.pk/story/2732102/alzarri-joseph-suspended-for-two-matches-on-unacceptable-behaviour
# link in express is https://www.express.pk/story/2732099/champions-trophy-no-hybrid-model-is-being-considered-sources
# link in express is https://www.express.pk/story/2732097/2nd-odi-australia-lost-2-early-wickets-against-pakistan
# link in express is https://www.express.pk/story/2732068/wpl-bcci-retention-2025
# link in express is https://www.express.pk/story/2732059/kanpur-test-india-bangladesh-demerit-point-icc-bcci
# link in express is https://www.express.pk/story/2732048/snooker-championship-masters-qatar-doha-muhammad-asif
# link in express is https://www.express.pk/story/2732045/pcb-one-day-tournament-karachi
# link in express is https://www.express.pk/story/2731999/chimpeinz-lig-mich-k-doran-flstin-ki-azadi-birz-aoiza-tsaoir-oaerl
# 	--> Successfully scraped 10 articles from page 2 of 'sports'.
# Scraping page 3 of category 'sports'...
# 	--> Found 10 articles on page 3 of 'sports'.
# link in express is https://www.express.pk/story/2731994/michael-clarke-explained-the-main-reason-for-the-clean-sweep-by-the-kiwis-on-home-ground
# link in express is https://www.express.pk/story/2731981/mohammad-rizwan-on-the-verge-of-breaking-sarfaraz-ahmeds-elite-record
# link in express is https://www.express.pk/story/2731978/sammy-calls-josephs-behaviour-to-leave-the-ground-unacceptable
# link in express is https://www.express.pk/story/2731967/olympic-boxer-imane-khelif-takes-legal-action-over-male-chromosomes-claims
# link in express is https://www.express.pk/story/2731964/jamiat-ke-zer-ahtamam-wafaqi-urdu-university-min-sports-week
# link in express is https://www.express.pk/story/2731961/pak-australia-series-2nd-odi-will-be-played-tomorrow
# link in express is https://www.express.pk/story/2731959/pakistan-cricketers-visit-jason-gillespies-academy-in-australia
# link in express is https://www.express.pk/story/2731948/former-pakistan-and-england-cricketer-defend-babar-azam-amid-online-criticism
# link in express is https://www.express.pk/story/2731945/west-indies-cricketer-leaves-field-after-a-heated-argument-with-captain
# link in express is https://www.express.pk/story/2731931/champions-trophy-yes-ya-no-likh-kar-do-bharat-ko-wazeh-pegham
# 	--> Successfully scraped 10 articles from page 3 of 'sports'.
# Scraping page 4 of category 'sports'...
# 	--> Found 10 articles on page 4 of 'sports'.
# link in express is https://www.express.pk/story/2731918/aleem-dars-key-role-in-pakistans-victory-over-england-what-advice-led-to-success
# link in express is https://www.express.pk/story/2731885/icc-latest-ranking
# link in express is https://www.express.pk/story/2731872/pakistan-sports-board-ka-olympic-association-ke-intakhabi-amal-par-tahafuzat-ka-izhar
# link in express is https://www.express.pk/story/2731820/muhammad-asif-became-world-snooker-champion-for-the-third-time
# link in express is https://www.express.pk/story/2731809/major-update-on-naseem-shah-ahead-of-second-odi-against-australia
# link in express is https://www.express.pk/story/2731798/pakistan-to-face-india-as-world-championship-of-legends-returns
# link in express is https://www.express.pk/story/2731782/champions-trophy-2025-new-led-floodlights-installed-in-gaddafi-stadium
# link in express is https://www.express.pk/story/2731777/champions-trophy-2025-the-schedule-is-likely-to-be-announced-next-week
# link in express is https://www.express.pk/story/2731776/ipl-players-drafts-it-will-be-held-in-jeddah-on-november-24
# link in express is https://www.express.pk/story/2731768/second-odi-2-major-changes-likely-in-the-pakistan-team
# 	--> Successfully scraped 10 articles from page 4 of 'sports'.
# Scraping page 5 of category 'sports'...
# 	--> Found 10 articles on page 5 of 'sports'.
# link in express is https://www.express.pk/story/2731765/mtnazaa-baksr-aiman-khlif-ki-aik-aor-miikl-rpor-lik-mrd-krar
# link in express is https://www.express.pk/story/2731762/josh-inglis-replaces-pat-cummins-to-become-australias-white-ball-captain-vs-pakistan
# link in express is https://www.express.pk/story/2731734/pakistans-muhammad-asif-reached-in-world-snooker-championship-final
# link in express is https://www.express.pk/story/2731732/icc-player-of-the-months-nominations-october-2024-noman-ali
# link in express is https://www.express.pk/story/2731694/india-pakistan-cricket-stars-to-unite-in-asia-xi-as-afro-asia-cup-eyes-comeback-after-two-decades
# link in express is https://www.express.pk/story/2731687/anrnishnl-kra-mkablo-mi-hs-lin-k-li-pakstani-dst-ros-roan
# link in express is https://www.express.pk/story/2731680/pakistan-and-uae-will-work-together-for-the-promotion-of-jujitsu
# link in express is https://www.express.pk/story/2731657/pak-v-aus-haris-rauf-highlights-pakistans-shortfall-in-first-odi-against-australia
# link in express is https://www.express.pk/story/2731640/pak-v-aus-ramiz-praise-pakistan-team-on-fightback-against-australia
# link in express is https://www.express.pk/story/2731633/same-old-story-ahmed-shehzads-reacts-on-pakistan-defeat
# 	--> Successfully scraped 10 articles from page 5 of 'sports'.
# Scraping page 6 of category 'sports'...
# 	--> Found 10 articles on page 6 of 'sports'.
# link in express is https://www.express.pk/story/2731627/mohammad-huraira-appointed-captain-of-pakistan-shaheens
# link in express is https://www.express.pk/story/2731620/pakvsa-fakhar-zaman-imam-ul-haq-likely-to-comeback-in-white-ball-squad
# link in express is https://www.express.pk/story/2731616/aus-v-pak-pakistan-t20i-team-prepares-for-australia-series-with-training-on-marble-surfaces
# link in express is https://www.express.pk/story/2731608/shakib-al-hasan-reported-for-suspect-bowling-action
# link in express is https://www.express.pk/story/2731601/aus-v-pak-will-naseem-shah-play-second-odi-after-injury-in-first-match
# link in express is https://www.express.pk/story/2731599/this-is-not-multan-pitch-baby-it-is-mcg
# link in express is https://www.express.pk/story/2731595/1st-odi-mohammad-rizwan-opened-up-after-australia-deafeat
# link in express is https://www.express.pk/story/2731577/salman-naseer-keliye-md-psl-ki-post-takhleeq
# link in express is https://www.express.pk/story/2731563/footballer-killed-in-lightning-during-match-in-peru
# link in express is https://www.express.pk/story/2731540/pakistan-women-set-to-host-england-new-zealand-and-zimbabwe-for-home-tours
# 	--> Successfully scraped 10 articles from page 6 of 'sports'.
# Scraping page 7 of category 'sports'...
# 	--> Found 10 articles on page 7 of 'sports'.
# link in express is https://www.express.pk/story/2731525/saim-ayub-and-irfan-khan-debut-odi-match
# link in express is https://www.express.pk/story/2731518/hockey-team-training-camp-starts-for-junior-asia-cup
# link in express is https://www.express.pk/story/2731513/wriddhiman-saha-wicket-keeper-announce-retirement
# link in express is https://www.express.pk/story/2731511/pak-vs-aus-mitchell-starc-achieves-milestone-on-home-soil-in-first-odi-against-pakistan
# link in express is https://www.express.pk/story/2731499/pak-vs-aus-pcb-chief-mohsin-naqvi-reacts-after-pakistans-first-odi-defeat-to-australia
# link in express is https://www.express.pk/story/2731478/noc-issued-to-indian-blind-cricket-team-to-come-to-pakistan
# link in express is https://www.express.pk/story/2731420/australia-ka-toss-jeet-kar-pakistan-ko-pehlay-batting-karne-ki-dawat
# link in express is https://www.express.pk/story/2731396/pcb-k-baber-azam
# link in express is https://www.express.pk/story/2731374/pakistan-army-win-national-swiming-championship-2024
# link in express is https://www.express.pk/story/2731328/trials-of-pakistan-womens-team-for-asia-cup-begin
# 	--> Successfully scraped 10 articles from page 7 of 'sports'.
#
# Scraping page 1 of category 'science'...
# 	--> Found 10 articles on page 1 of 'science'.
# link in express is https://www.express.pk/story/2732211/youtube-interface-playback-slider
# link in express is https://www.express.pk/story/2732166/australia-bans-social-media
# link in express is https://www.express.pk/story/2732054/secret-space-weapon-chinese-scientists-star-wars
# link in express is https://www.express.pk/story/2732036/solar-flare-intense-energy-emission-nasa
# link in express is https://www.express.pk/story/2731911/nasa-dragon-fly-mission-saturn-titan-moon
# link in express is https://www.express.pk/story/2731867/cryptocurrency-bitcoin-price-jumps-donald-trump-president
# link in express is https://www.express.pk/story/2731855/meta-facebook-instagram-whatsapp-data-sharing-south-korea-fine
# link in express is https://www.express.pk/story/2731821/donald-trump-praises-elon-in-victory-speech
# link in express is https://www.express.pk/story/2731738/helicopter-chopper-airbus-high-speed
# link in express is https://www.express.pk/story/2731691/lki-s-bna-dnia-ka-pla-silaei-khla-k-li-roan
# 	--> Successfully scraped 10 articles from page 1 of 'science'.
# Scraping page 2 of category 'science'...
# 	--> Found 10 articles on page 2 of 'science'.
# link in express is https://www.express.pk/story/2731682/techno-spark-30c-smart-phone
# link in express is https://www.express.pk/story/2731663/two-suicides-lead-family-to-sue-tiktok
# link in express is https://www.express.pk/story/2731638/iss-supplies-transported
# link in express is https://www.express.pk/story/2731610/aliens-interested-in-us-nuclear-arms
# link in express is https://www.express.pk/story/2731574/air-taxi-airbus-evtols
# link in express is https://www.express.pk/story/2731509/bio-printer-human-cells-tissue-technology-fast
# link in express is https://www.express.pk/story/2731479/mexican-maya-civilization-discovered
# link in express is https://www.express.pk/story/2731471/4000-years-old-town-found-in-saudi-arabia
# link in express is https://www.express.pk/story/2731455/iq-check-in-in-vitro-babies
# link in express is https://www.express.pk/story/2731324/chatgpt-new-feature
# 	--> Successfully scraped 10 articles from page 2 of 'science'.
# Scraping page 3 of category 'science'...
# 	--> Found 10 articles on page 3 of 'science'.
# link in express is https://www.express.pk/story/2731323/chini-foj-kile-nia-a-aei-mal-tiar
# link in express is https://www.express.pk/story/2731249/nasa-spiral-galaxies-universe-jet-propulsion
# link in express is https://www.express.pk/story/2731236/artemis-mission-moon-landing-nasa
# link in express is https://www.express.pk/story/2731220/ghair-akhalaqi-mawad-tik-tok-par-ek-laakh-13-hazar-133-accounts-block
# link in express is https://www.express.pk/story/2731174/aozon-mi-sorakh-bhali-ki-trf-gamzn
# link in express is https://www.express.pk/story/2731113/bacteria-carbon-consumption-pollution-ocean-climate-change
# link in express is https://www.express.pk/story/2731099/water-purification-device-recycled-tires-solar-technology
# link in express is https://www.express.pk/story/2731069/400-years-old-vampire-womans-face
# link in express is https://www.express.pk/story/2731068/whatsapp-hackings-in-pakistani
# link in express is https://www.express.pk/story/2731056/travel-from-karachi-to-london-hypersonic-plane
# 	--> Successfully scraped 10 articles from page 3 of 'science'.
# Scraping page 4 of category 'science'...
# 	--> Found 10 articles on page 4 of 'science'.
# link in express is https://www.express.pk/story/2731054/indonesia-ban-iphone-16
# link in express is https://www.express.pk/story/2731047/whatsapp-new-ai-feature
# link in express is https://www.express.pk/story/2730988/mars-plants-grow-plans
# link in express is https://www.express.pk/story/2730963/google-youtube-russia-fine-court-billion-trillion-dollars
# link in express is https://www.express.pk/story/2730939/meta-instagram-facebook-ai-screen-time
# link in express is https://www.express.pk/story/2730838/trump-ke-social-media-platform-ne-x-ko-peche-chor-dia
# link in express is https://www.express.pk/story/2730833/apple-mac-mini-released-smallest-computer
# link in express is https://www.express.pk/story/2730825/aei-fon-ap-i-k-baad-sarfin-ko-msael-ka-samna
# link in express is https://www.express.pk/story/2730800/chinese-company-concord-supersonic-aviation-technology
# link in express is https://www.express.pk/story/2730772/noah-ark-scientists-research-british-great-flood-location
# 	--> Successfully scraped 10 articles from page 4 of 'science'.
# Scraping page 5 of category 'science'...
# 	--> Found 10 articles on page 5 of 'science'.
# link in express is https://www.express.pk/story/2730670/malik-bhar-mein-1426-whatsapp-accounts-heck-honay-ka-inkishaaf
# link in express is https://www.express.pk/story/2730628/mulkbhar-aikhazacharsoosezaid-whatsapp-accounts-hack
# link in express is https://www.express.pk/story/2730624/nasa-space-station-lunar-base-artemis
# link in express is https://www.express.pk/story/2730595/trees-species-extinction-us-conservation
# link in express is https://www.express.pk/story/2730529/gogl-ka-krom-mi-taktor-trin-a-aei-iknaloji-astaamal-krn-mnsob
# link in express is https://www.express.pk/story/2730464/apple-intelligence-ai-features-os
# link in express is https://www.express.pk/story/2730454/instagram-video-quality-change-popular
# link in express is https://www.express.pk/story/2730424/nasa-spacecraft-technology-engineers
# link in express is https://www.express.pk/story/2730322/chin-ki-ioniorsi-mi-thkikati-mrkz-pakstani-saens-dan-s-mnsob
# link in express is https://www.express.pk/story/2730273/pakistani-mobile-phones-on-the-rise
# 	--> Successfully scraped 10 articles from page 5 of 'science'.
# Scraping page 6 of category 'science'...
# 	--> Found 10 articles on page 6 of 'science'.
# link in express is https://www.express.pk/story/2730261/whatsapps-new-barcode-feature
# link in express is https://www.express.pk/story/2730236/a-aei-iknaloji-oi-oei-io-ki-tshkhis-mi-mddgar-krar
# link in express is https://www.express.pk/story/2730186/climate-change-temperature-un-report-cop
# link in express is https://www.express.pk/story/2730177/apple-intelligence-security-challenge
# link in express is https://www.express.pk/story/2730170/world-not-ready-for-agi
# link in express is https://www.express.pk/story/2730120/drone-cart-revealed
# link in express is https://www.express.pk/story/2730110/robotics-in-fossilized-models
# link in express is https://www.express.pk/story/2730090/ai-killed-teen
# link in express is https://www.express.pk/story/2730076/nei-ksm-ki-baeio-igri-aibl-biri-aijad
# link in express is https://www.express.pk/story/2730050/lnk-an-pr-kroo-ioro-jrman-aaaed
# 	--> Successfully scraped 10 articles from page 6 of 'science'.
# Scraping page 7 of category 'science'...
# 	--> Found 10 articles on page 7 of 'science'.
# link in express is https://www.express.pk/story/2730012/passport-clearance-not-needed-at-singapore-airport
# link in express is https://www.express.pk/story/2730003/solar-railway-tracks-in-switzerland
# link in express is https://www.express.pk/story/2729994/tim-cook-unaware-of-the-iphone-feature
# link in express is https://www.express.pk/story/2729964/kmionkishn-silae-zmini-mdar-s-bar-nklt-i-tba
# link in express is https://www.express.pk/story/2729960/pakstan-mi-rozan-aik-zar-afrad-falj-ka-shkar-ot-i-marin
# link in express is https://www.express.pk/story/2729927/soch-ki-nei-ksm-ssm-0-kia
# link in express is https://www.express.pk/story/2729752/k-ak-ka-pakstani-nojoano-kile-ijil-sifi-mkabl-ka-aaalan
# link in express is https://www.express.pk/story/2729732/Meta-ka-jalsazi-se-nimatne-kay-liay-aham-aqdaam
# link in express is https://www.express.pk/story/2729723/aipl-apna-anili-jns-fichr-kb-mtaaarf-krae-ga
# link in express is https://www.express.pk/story/2729669/k-ak-ka-pi-i-a-k-sat-ml-kr-ijil-sifi-mkabl-mnaakd-krn-ka-aaalan
# 	--> Successfully scraped 10 articles from page 7 of 'science'.
#
# Scraping page 1 of category 'world'...
# 	--> Found 10 articles on page 1 of 'world'.
# link in express is https://www.express.pk/story/2732238/nidrlinz-mi-asraeili-f-bal-shaekin-ka-mkhalf-grop-s-tsadm-ahtjaj-pr-pabndi-aaaed
# link in express is https://www.express.pk/story/2732232/onl-rmp-k-mbin-ktl-ka-mnsob-amrika-mi-airani-shri-pr-frd-jrm-aaaed
# link in express is https://www.express.pk/story/2732192/us-9th11-khalid-sheikh-execution-death-sentenced-cancil-deal
# link in express is https://www.express.pk/story/2732189/fbal-mich-mi-flstini-prchm-ki-bihrmti-pr-tsadm-11-asraeili-zkhmi-aor-2-lapta
# link in express is https://www.express.pk/story/2732183/indian-army-major-suicide-shooting-himself-kashmir
# link in express is https://www.express.pk/story/2732172/hasan-nasarullah-uncle-alongwith-4sons-martyred-israeli-attack-lebanon
# link in express is https://www.express.pk/story/2732144/donald-trump-uselection2024-white-house-chief-of-staff-susie-wiles
# link in express is https://www.express.pk/story/2732135/barti-foj-ki-riasti-dsht-grdi-mi-2-kshmiri-nojoan-shid-1
# link in express is https://www.express.pk/story/2732130/indian-rupee-falls-to-all-time-low-against-us-dollar
# link in express is https://www.express.pk/story/2732101/amriki-foji-jj-n-naen-alion-k-mbin-masrmaen-k-sat-il-bhal-krdi
# 	--> Successfully scraped 10 articles from page 1 of 'world'.
# Scraping page 2 of category 'world'...
# 	--> Found 10 articles on page 2 of 'world'.
# link in express is https://www.express.pk/story/2732094/trump-ke-kehnay-par-bhi-ohda-nahi-choroon-ga-sarbarah-amrici-firl-reserves
# link in express is https://www.express.pk/story/2732069/asraeil-ka-jaz-saz-kmpni-s-25-aif-15-laka-tiar-khridn-ka-maaad
# link in express is https://www.express.pk/story/2732058/kmla-irs-ki-shkst-ba-dchka-jobaein
# link in express is https://www.express.pk/story/2732043/hzb-all-k-rak-hml-mi-aik-asraeili-foji-lak-aor-3-zkhmi
# link in express is https://www.express.pk/story/2732039/barak-obama-on-trump-victory-uselection2024-agaianst-kamala-harris
# link in express is https://www.express.pk/story/2732032/switzerland-burqa-niqab-ban
# link in express is https://www.express.pk/story/2732020/donald-trump-gop-israel-hamas-lebanon-war
# link in express is https://www.express.pk/story/2732009/israel-attack-in-lebanons-on-ancient-baalbek-killed-40
# link in express is https://www.express.pk/story/2731989/uselection2024-vp-jd-vance-america-second-lady-usha-vance-indian
# link in express is https://www.express.pk/story/2731988/donald-trump-sex-scandals-wives-children
# 	--> Successfully scraped 10 articles from page 2 of 'world'.
# Scraping page 3 of category 'world'...
# 	--> Found 10 articles on page 3 of 'world'.
# link in express is https://www.express.pk/story/2731976/trump-truth-social-increase
# link in express is https://www.express.pk/story/2731958/australian-foreign-minister-ka-india-par-sikhs-ko-target-krny-ka-ilzam
# link in express is https://www.express.pk/story/2731943/germany-mein-hakoomati-ittehaad-ka-sharazah-bikhar-gaya-qabal-az-waqt-intikhabaat-mutawaqqa
# link in express is https://www.express.pk/story/2731942/intikhabi-muhim-mein-sath-dainay-walon-ka-shukriya-shikast-ke-baad-kamla-hirs-ka-khitaab
# link in express is https://www.express.pk/story/2731939/amreci-sadaarti-muhim-par-16-arab-dollar-kharch
# link in express is https://www.express.pk/story/2731922/afghan-talban-ko-rmp-ki-kamiabi-k-baad-amrika-k-sat-ne-dor-ki-amid
# link in express is https://www.express.pk/story/2731919/harris-called-trump-to-concede-us-presidential-election
# link in express is https://www.express.pk/story/2731916/trump-kamyabi-francegemany-europeanunion-mutahid-zor
# link in express is https://www.express.pk/story/2731893/chin-komi-raz-lik-krn-khfi-aijnsi-k-sabk-alkarko-szae-mot
# link in express is https://www.express.pk/story/2731886/indian-occupied-kashmir-artical370-restore-resolution-passed
# 	--> Successfully scraped 10 articles from page 3 of 'world'.
# Scraping page 4 of category 'world'...
# 	--> Found 10 articles on page 4 of 'world'.
# link in express is https://www.express.pk/story/2731881/americi-intikhabaat-ki-tasveeri-jhalkiyan
# link in express is https://www.express.pk/story/2731876/donald-trump-states-win
# link in express is https://www.express.pk/story/2731865/trump-uselection2024-love-wife-malania-trump
# link in express is https://www.express.pk/story/2731851/gaza-min-filsateeni-bachi-hind-rajab-ki-shahadat-ki-ai-video-jari
# link in express is https://www.express.pk/story/2731850/hamas-on-trump-victory-ion-uselection2024
# link in express is https://www.express.pk/story/2731842/israel-india-uk-turkey-congratulation-trump-victory-uselection2024
# link in express is https://www.express.pk/story/2731841/china-on-trump-victory-uselection2024
# link in express is https://www.express.pk/story/2731830/donald-trump-popular-votes-7crore
# link in express is https://www.express.pk/story/2731827/amriki-election-min-karachi-ke-doctor-suleman-laalani-ki-fatah
# link in express is https://www.express.pk/story/2731812/trump-republican-won-senate-election-too
# 	--> Successfully scraped 10 articles from page 4 of 'world'.
# Scraping page 5 of category 'world'...
# 	--> Found 10 articles on page 5 of 'world'.
# link in express is https://www.express.pk/story/2731810/amriki-intakhabat-min-pakistani-nazad-salman-bhojani-bhi-kamiyab
# link in express is https://www.express.pk/story/2731787/trump-won-uselection2024-kamala-harris-loss
# link in express is https://www.express.pk/story/2731758/alikshn-mnsfan-ar-gia-to-shkst-tslim-kro-ga-onl-rmp
# link in express is https://www.express.pk/story/2731753/amrici-intikhabaat-chand-reyaston-mein-barf-baari-polling-ka-amal-jari
# link in express is https://www.express.pk/story/2731750/donald-trmp-ne-intikhabi-nataij-dekhnay-ke-liye-intizamaa-kar-liye
# link in express is https://www.express.pk/story/2731748/america-hyper-sonic-missile-tajarbay-keliye-tayyar-bartanwi-media
# link in express is https://www.express.pk/story/2731746/israelwazirazam-wazirdifa-bartaraf
# link in express is https://www.express.pk/story/2731731/donald-trmp-ki-musalman-votoron-se-vote-ki-appeal
# link in express is https://www.express.pk/story/2731712/uselection2024-elone-musk-10lac-dollers-voters-trump
# link in express is https://www.express.pk/story/2731705/uselection2024-fia-casa-thread-russia
# 	--> Successfully scraped 10 articles from page 5 of 'world'.
# Scraping page 6 of category 'world'...
# 	--> Found 10 articles on page 6 of 'world'.
# link in express is https://www.express.pk/story/2731696/uselection2024-timezone-poling-voters-result
# link in express is https://www.express.pk/story/2731689/uselection2024-presidential-election-governors-mayors-congressmen
# link in express is https://www.express.pk/story/2731674/kamala-harris-ki-jeet-kay-liay-bharat-me-pooja
# link in express is https://www.express.pk/story/2731660/uselection2024-first-result-poling-trump-kamala-harris
# link in express is https://www.express.pk/story/2731654/uselection2024-who-cant-cast-vote
# link in express is https://www.express.pk/story/2731641/indian-soldier-suicide-in-kashmir
# link in express is https://www.express.pk/story/2731629/uselection2024-which-state-most-wins-state
# link in express is https://www.express.pk/story/2731602/sdr-mntkhb-on-pr-bghir-dstaoiz-aan-oalo-ko-i-por-krdo-ga-onl-rmp
# link in express is https://www.express.pk/story/2731592/us-election-2024-qabal-az-waqt-voton-ki-tadaad-81-million-se-tajawaz-kar-gayi
# link in express is https://www.express.pk/story/2731591/afghan-naazim-alamor-se-blaajazt-mulaqaat-maldip-ne-high-commissioner-ko-wapas-bulaa-liya
# 	--> Successfully scraped 10 articles from page 6 of 'world'.
# Scraping page 7 of category 'world'...
# 	--> Found 10 articles on page 7 of 'world'.
# link in express is https://www.express.pk/story/2731580/amrici-aaj-duniya-ka-naya-hukmaran-chunain-ge
# link in express is https://www.express.pk/story/2731517/uselection2024-why-tuesday-only
# link in express is https://www.express.pk/story/2731505/indian-army-plan-mig29-crash
# link in express is https://www.express.pk/story/2731491/donald-trump-whitehouse-or-jail-uselection2024
# link in express is https://www.express.pk/story/2731490/kamala-harris-donald-trump-uselection2024-muslims-voters
# link in express is https://www.express.pk/story/2731476/akhri-dm-tk-asraeili-foj-k-samn-rn-oal-snoar-3-dn-s-bok-t-pos-marm
# link in express is https://www.express.pk/story/2731464/iran-military-helicopter-crash-irgc-commander-alongwith-pilot-killed
# link in express is https://www.express.pk/story/2731458/india-bus-fall-into-gorge-killed-36
# link in express is https://www.express.pk/story/2731448/iran-executed-jewish-murder-case-israel-america-condemn
# link in express is https://www.express.pk/story/2731418/amrici-raye-dahindgaan-kal-naye-saddar-ka-intikhab-karen-ge
# 	--> Successfully scraped 10 articles from page 7 of 'world'.

# %% [markdown]
# ### Imports for data cleaning

# %%
import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score,confusion_matrix

import kagglehub

# %% [markdown]
# ### Data Cleaning
#
# - `\u0600-\u06FF` specifies a Unicode range. This range includes characters from the Arabic script, which covers most of Urdu.
# - We have removed punctuations and numbers here.
# - Included Stopwords Cleaning

# %%
df = pd.read_csv(r"articles.csv")
df = df.dropna().reset_index(drop=True)
df = df.drop_duplicates(subset=['Contents']).reset_index(drop=True)

print(pd.value_counts(df["Gold Labels"]))
print("Total number of articles: " ,len(set(df["Contents"])))

# DOWNLOADED URDU STOPWORDS
# SEE urdu_stopwords.txt file

stopwords_file = "urdu_stopwords.txt" 
with open(stopwords_file, "r", encoding="utf-8") as f:
        urdu_stopwords = [line.strip() for line in f]

print(urdu_stopwords)

def clean_text(text):
    text = re.sub(r'[^\u0600-\u06FF\s]', '', text)
    text = ' '.join([word for word in text.split() if word not in urdu_stopwords])
    return text

df_cleaned = df.copy()
df_cleaned['Contents'] = df_cleaned['Contents'].apply(clean_text)
# Out:
# C:\Users\Muhammad Muiz Farhan\AppData\Local\Temp\ipykernel_19852\3812139567.py:5: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   print(pd.value_counts(df["Gold Labels"]))
# Gold Labels
# entertainment         229
# world                 229
# sports                228
# business              222
# science-technology    213
# Name: count, dtype: int64
# Total number of articles:  1121
# ['آئی', 'آئے', 'آج', 'آخر', 'آخرکبر', 'آدهی', 'آًب', 'آٹھ', 'آیب', 'اة', 'اخبزت', 'اختتبم', 'ادھر', 'ارد', 'اردگرد', 'ارکبى', 'اش', 'اضتعوبل', 'اضتعوبلات', 'اضطرذ', 'اضکب', 'اضکی', 'اضکے', 'اطراف', 'اغیب', 'افراد', 'الگ', 'اور', 'اوًچب', 'اوًچبئی', 'اوًچی', 'اوًچے', 'اى', 'اً', 'اًذر', 'اًہیں', 'اٹھبًب', 'اپٌب', 'اپٌے', 'اچھب', 'اچھی', 'اچھے', 'اکثر', 'اکٹھب', 'اکٹھی', 'اکٹھے', 'اکیلا', 'اکیلی', 'اکیلے', 'اگرچہ', 'اہن', 'ایطے', 'ایک', 'ب', 'ت', 'تبزٍ', 'تت', 'تر', 'ترتیت', 'تریي', 'تعذاد', 'تن', 'تو', 'توبم', 'توہی', 'توہیں', 'تٌہب', 'تک', 'تھب', 'تھوڑا', 'تھوڑی', 'تھوڑے', 'تھی', 'تھے', 'تیي', 'ثب', 'ثبئیں', 'ثبترتیت', 'ثبری', 'ثبرے', 'ثبعث', 'ثبلا', 'ثبلترتیت', 'ثبہر', 'ثدبئے', 'ثرآں', 'ثراں', 'ثرش', 'ثعذ', 'ثغیر', 'ثلٌذ', 'ثلٌذوثبلا', 'ثلکہ', 'ثي', 'ثٌب', 'ثٌبرہب', 'ثٌبرہی', 'ثٌبرہے', 'ثٌبًب', 'ثٌذ', 'ثٌذکرو', 'ثٌذکرًب', 'ثٌذی', 'ثڑا', 'ثڑوں', 'ثڑی', 'ثڑے', 'ثھر', 'ثھرا', 'ثھراہوا', 'ثھرپور', 'ثھی', 'ثہت', 'ثہتر', 'ثہتری', 'ثہتریي', 'ثیچ', 'ج', 'خب', 'خبرہب', 'خبرہی', 'خبرہے', 'خبهوظ', 'خبًب', 'خبًتب', 'خبًتی', 'خبًتے', 'خبًٌب', 'خت', 'ختن', 'خجکہ', 'خص', 'خططرذ', 'خلذی', 'خو', 'خواى', 'خوًہی', 'خوکہ', 'خٌبة', 'خگہ', 'خگہوں', 'خگہیں', 'خیطب', 'خیطبکہ', 'در', 'درخبت', 'درخہ', 'درخے', 'درزقیقت', 'درضت', 'دش', 'دفعہ', 'دلچطپ', 'دلچطپی', 'دلچطپیبں', 'دو', 'دور', 'دوراى', 'دوضرا', 'دوضروں', 'دوضری', 'دوضرے', 'دوًوں', 'دکھبئیں', 'دکھبتب', 'دکھبتی', 'دکھبتے', 'دکھبو', 'دکھبًب', 'دکھبیب', 'دی', 'دیب', 'دیتب', 'دیتی', 'دیتے', 'دیر', 'دیٌب', 'دیکھو', 'دیکھٌب', 'دیکھی', 'دیکھیں', 'دے', 'ر', 'راضتوں', 'راضتہ', 'راضتے', 'رریعہ', 'رریعے', 'رکي', 'رکھ', 'رکھب', 'رکھتب', 'رکھتبہوں', 'رکھتی', 'رکھتے', 'رکھی', 'رکھے', 'رہب', 'رہی', 'رہے', 'ز', 'زبصل', 'زبضر', 'زبل', 'زبلات', 'زبلیہ', 'زصوں', 'زصہ', 'زصے', 'زقبئق', 'زقیتیں', 'زقیقت', 'زکن', 'زکویہ', 'زیبدٍ', 'صبف', 'صسیر', 'صفر', 'صورت', 'صورتسبل', 'صورتوں', 'صورتیں', 'ض', 'ضبت', 'ضبتھ', 'ضبدٍ', 'ضبرا', 'ضبرے', 'ضبل', 'ضبلوں', 'ضت', 'ضرور', 'ضرورت', 'ضروری', 'ضلطلہ', 'ضوچ', 'ضوچب', 'ضوچتب', 'ضوچتی', 'ضوچتے', 'ضوچو', 'ضوچٌب', 'ضوچی', 'ضوچیں', 'ضکب', 'ضکتب', 'ضکتی', 'ضکتے', 'ضکٌب', 'ضکی', 'ضکے', 'ضیذھب', 'ضیذھی', 'ضیذھے', 'ضیکٌڈ', 'ضے', 'طرف', 'طریق', 'طریقوں', 'طریقہ', 'طریقے', 'طور', 'طورپر', 'ظبہر', 'ع', 'عذد', 'عظین', 'علاقوں', 'علاقہ', 'علاقے', 'علاوٍ', 'عووهی', 'غبیذ', 'غخص', 'غذ', 'غروع', 'غروعبت', 'غے', 'فرد', 'فی', 'ق', 'قجل', 'قجیلہ', 'قطن', 'لئے', 'لا', 'لازهی', 'لو', 'لوجب', 'لوجی', 'لوجے', 'لوسبت', 'لوسہ', 'لوگ', 'لوگوں', 'لڑکپي', 'لگتب', 'لگتی', 'لگتے', 'لگٌب', 'لگی', 'لگیں', 'لگے', 'لی', 'لیب', 'لیٌب', 'لیں', 'لے', 'ه', 'هتعلق', 'هختلف', 'هسترم', 'هسترهہ', 'هسطوش', 'هسیذ', 'هطئلہ', 'هطئلے', 'هطبئل', 'هطتعول', 'هطلق', 'هعلوم', 'هػتول', 'هلا', 'هوکي', 'هوکٌبت', 'هوکٌہ', 'هٌبضت', 'هڑا', 'هڑًب', 'هڑے', 'هکول', 'هگر', 'هہرثبى', 'هیرا', 'هیری', 'هیرے', 'هیں', 'و', 'وار', 'والے', 'وٍ', 'ًئی', 'ًئے', 'ًب', 'ًبپطٌذ', 'ًبگسیر', 'ًطجت', 'ًقطہ', 'ًو', 'ًوخواى', 'ًکبلٌب', 'ًکتہ', 'ًہ', 'ًہیں', 'ًیب', 'ًے', 'ٓ آش', 'ٹھیک', 'پبئے', 'پبش', 'پبًب', 'پبًچ', 'پر', 'پراًب', 'پطٌذ', 'پل', 'پورا', 'پوچھب', 'پوچھتب', 'پوچھتی', 'پوچھتے', 'پوچھو', 'پوچھوں', 'پوچھٌب', 'پوچھیں', 'پچھلا', 'پھر', 'پہلا', 'پہلی', 'پہلےضی', 'پہلےضے', 'پہلےضےہی', 'پیع', 'چبر', 'چبہب', 'چبہٌب', 'چبہے', 'چلا', 'چلو', 'چلیں', 'چلے', 'چکب', 'چکی', 'چکیں', 'چکے', 'چھوٹب', 'چھوٹوں', 'چھوٹی', 'چھوٹے', 'چھہ', 'چیسیں', 'ڈھوًڈا', 'ڈھوًڈلیب', 'ڈھوًڈو', 'ڈھوًڈًب', 'ڈھوًڈی', 'ڈھوًڈیں', 'ک', 'کئی', 'کئے', 'کب', 'کبفی', 'کبم', 'کت', 'کجھی', 'کرا', 'کرتب', 'کرتبہوں', 'کرتی', 'کرتے', 'کرتےہو', 'کررہب', 'کررہی', 'کررہے', 'کرو', 'کرًب', 'کریں', 'کرے', 'کطی', 'کل', 'کن', 'کوئی', 'کوتر', 'کورا', 'کوروں', 'کورٍ', 'کورے', 'کوطي', 'کوى', 'کوًطب', 'کوًطی', 'کوًطے', 'کھولا', 'کھولو', 'کھولٌب', 'کھولی', 'کھولیں', 'کھولے', 'کہ', 'کہب', 'کہتب', 'کہتی', 'کہتے', 'کہو', 'کہوں', 'کہٌب', 'کہی', 'کہیں', 'کہے', 'کی', 'کیب', 'کیطب', 'کیطرف', 'کیطے', 'کیلئے', 'کیوًکہ', 'کیوں', 'کیے', 'کے', 'کےثعذ', 'کےرریعے', 'گئی', 'گئے', 'گب', 'گرد', 'گروٍ', 'گروپ', 'گروہوں', 'گٌتی', 'گی', 'گیب', 'گے', 'ہر', 'ہن', 'ہو', 'ہوئی', 'ہوئے', 'ہوا', 'ہوبرا', 'ہوبری', 'ہوبرے', 'ہوتب', 'ہو ...

# %%
print("\n\nUncleaned data example")
print(df['Contents'][60:70])
print("--------"*7)
print("\n\n\n")

print("Cleaned data example")
print(df_cleaned['Contents'][60:70])
df_cleaned.to_csv('cleaned.csv', index=False)
# Out:
# Uncleaned data example
# 60    وفاقی وزیر خزانہ محمد اورنگزیب نے کہا ہے کہ پا...
# 61    کراچی: کاروباری ہفتے کے  آخری روز ملکی تبادلہ ...
# 62    پاکستان اسٹاک ایکسچینج کے 100 انڈیکس نے نئی بل...
# 63    اسلام آباد: حکومت نے موسم سرما اور بہار میں ا...
# 64    کراچی: ملک بھر میں مسلسل 3 روز تک کمی کے بعد ا...
# 65    کراچی: اسٹیٹ بینک نے ترسیلات زر کی تفصیلات جار...
# 66    لاہور: پنجاب حکومت نے عالمی مالیاتی ادارے کی ش...
# 67    اسلام آباد: شہباز شریف کی قیادت میں حکومت نے ...
# 68    اسلام آباد: حکومت نے شوگر ملز ایسوسی ایشن کی ...
# 69    اسلام آباد: پاکستان میں فروخت ہونے والی 50 فی...
# Name: Contents, dtype: object
# --------------------------------------------------------
#
#
#
#
# Cleaned data example
# 60    وفاقی وزیر خزانہ محمد اورنگزیب نے کہا پاکستان ...
# 61    کراچی کاروباری ہفتے آخری روز ملکی تبادلہ منڈیو...
# 62    پاکستان اسٹاک ایکسچینج انڈیکس نے نئی بلندی کو ...
# 63    اسلام آباد حکومت نے موسم سرما بہار میں اضافی ...
# 64    کراچی ملک بھر میں مسلسل روز کمی بعد آج سونے ق...
# 65    کراچی اسٹیٹ بینک نے ترسیلات زر تفصیلات جاری کر...
# 66    لاہور پنجاب حکومت نے عالمی مالیاتی ادارے شرائط...
# 67    اسلام آباد شہباز شریف قیادت میں حکومت نے آئی...
# 68    اسلام آباد حکومت نے شوگر ملز ایسوسی ایشن مزید...
# 69    اسلام آباد پاکستان میں فروخت ہونے والی فیصد س...
# Name: Contents, dtype: object

# %% [markdown]
# ## Now you can see a `cleaned.csv` file! We will be using this for all our models.
